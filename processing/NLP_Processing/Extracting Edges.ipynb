# %%
import json
import pprint

with open('upd_json__.json') as f:
    data = json.load(f)

# %%
verb_set = []
for companykey in data.keys():
    print (companykey)
    if "IDA Ireland" in companykey:
        continue
    else:
        GD_json = data[companykey]
        for key in GD_json:
            if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
                print ('      '+key)
                if isinstance (GD_json[key][2],dict):
                    pos = GD_json[key][2]
                elif isinstance (GD_json[key][3],dict):
                    pos = GD_json[key][3]
                else:
                    continue
                for sentence in pos.keys():
                    for item in pos[sentence].replace("(","").split(')'):
                        if len(item.split(','))>1:
                            if 'VB' in item.split(',')[1]:
                                #print (item.split(',')[0])
                                verb_set.append(item.split(',')[0])
print(len(verb_set))
# Out:
# LinkedIn Pulse
#       History[edit]
#       Intro
# Drawbridge (company)
#       History[edit]
#       Technology[edit]
#       Reception[edit]
#       Financials[edit]
#       Intro
# Glassdoor
#       Founding[edit]
#       Website[edit]
#       Reports[edit]
#       Financing[edit]
#       Awards[edit]
#       Intro
# Bright.com
#       Intro
# SlideShare
#       History[edit]
#       Zipcasts[edit]
#       Intro
# LinkedIn
#       Company overview[edit]
#       History[edit]
#       Membership[edit]
#       Future plans[edit]
#       New user interface in 2017[edit]
#       Discontinued features[edit]
#       Business units[edit]
#       Reception[edit]
#       International restrictions[edit]
#       SNA LinkedIn[edit]
#       Surveillance and NSA program[edit]
#       Criticism[edit]
#       Science[edit]
#       Intro
# Wirecard
#       Products and services[edit]
#       Wirecard and the Financial Times controversy[edit]
#       Financial data[edit]
# ...

# %%
from nltk.stem import LancasterStemmer
lancaster=LancasterStemmer()

stem_set = []
for w in verb_set:
    stem_set.append(lancaster.stem(lancaster.stem(w.replace("'",""))))
    
hash_map = {}
for word in stem_set:        
    if word in hash_map:
        hash_map[word] = hash_map[word] + 1
    else:
        hash_map[word] = 1
import operator
sorted_hashmap = sorted(hash_map.items(), key=operator.itemgetter(1),reverse=True)  
pprint.pprint(sorted_hashmap)
# Out:
# [('us', 1000),
#  ('includ', 929),
#  ('allow', 554),
#  ('annount', 433),
#  ('provid', 393),
#  ('cre', 376),
#  ('relea', 340),
#  ('launch', 318),
#  ('ad', 300),
#  ('cal', 284),
#  ('develop', 279),
#  ('mak', 277),
#  ('follow', 272),
#  ('receiv', 263),
#  ('bas', 227),
#  ('mad', 220),
#  ('off', 217),
#  ('found', 214),
#  ('becam', 210),
#  ('accord', 208),
#  ('op', 203),
#  ('work', 198),
#  ('said', 192),
#  ('support', 183),
#  ('acquir', 181),
#  ('publ', 173),
#  ('giv', 163),
#  ('report', 163),
#  ('introduc', 152),
#  ('', 152),
#  ('tak', 152),
#  ('beg', 151),
#  ('start', 151),
#  ('en', 149),
#  ('serv', 145),
#  ('upd', 144),
#  ('stat', 144),
#  ('run', 142),
#  ('becom', 137),
#  ('feat', 132),
#  ('requir', 132),
#  ('writ', 128),
#  ('design', 127),
#  ('known', 126),
#  ('distribut', 126),
#  ('post', 122),
#  ('describ', 120),
#  ('led', 115),
#  ('host', 113),
#  ('join', 113),
#  ('continu', 113),
#  ('chang', 108),
#  ('show', 107),
#  ('com', 106),
# ...

# %%
f = open('fund', "w")
    
import re
for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key) and ('Philanthropy' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    tuple_item = item.split(',')
                    if len(tuple_item)>1:
                        if 'VB' in tuple_item[1]:
                            if ('fund' in tuple_item[0]) and ('refund' not in tuple_item[0]) and ('fundraising' not in tuple_item[0]):
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NNP' in x.split(',')[1])):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    f.write(str(companykey) + ',' + str(store) + '\n')
f.close()
# Out:
# ********************************************
# Drawbridge (company)
# 		Financials[edit]
# 			('Drawbridge', 'NNP')('received', 'VBD')('funding', 'VBG')('Sequoia', 'NNP')('Capital', 'NNP')(',', ',')('Kleiner', 'NNP')('Perkins', 'NNP')(',', ',')('Northgate', 'NNP')('Capital', 'NNP')(',', ',')('Mitsui', 'NNP')('Co..', 'NN')
# ["'Drawbridge'", "'received'", "'funding'", "'Sequoia'", "'Capital'", "'Kleiner'", "'Perkins'", "'Northgate'", "'Capital'", "'Mitsui'"]
# ********************************************
# Viadeo
# 		Company information[edit]
# 			('November', 'NNP')('2006', 'CD')('August', 'NNP')('2007', 'CD')(',', ',')('Viadeo', 'NNP')('raised', 'VBD')('€5', 'CD')('million', 'CD')('twice', 'RB')('funding', 'VBG')('investors', 'NNS')('AGF', 'NNP')('Private', 'NNP')('Equity', 'NNP')('Ventech', 'NNP')('.', '.')
# ["'November'", "'August'", "'Viadeo'", "'raised'", "'funding'", "'AGF'", "'Private'", "'Equity'", "'Ventech'"]
# ********************************************
# Spring.me
# ...

# %%
f = open('acquir', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'VB' in item.split(',')[1]:
                            if 'acquir' in item.split(',')[0]:
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NNP' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    f.write(str(companykey) + ',' + str(store) + '\n')
f.close()
# Out:
# ********************************************
# Glassdoor
# 		Website[edit]
# 			('company', 'NN')('also', 'RB')('allows', 'VBZ')('users', 'NNS')('post', 'VBP')('potential', 'JJ')('job', 'NN')('interview', 'NN')('questions', 'NNS')('might', 'MD')('asked', 'VBD')('certain', 'JJ')('companies', 'NNS')(',', ',')('acquired', 'VBD')('interviewed', 'VBN')('job', 'NN')('candidates', 'NNS')(',', ',')('addition', 'NN')('information', 'NN')('used', 'VBD')('prepare', 'VB')('job', 'NN')('applications', 'NNS')('.', '.')
# ["'allows'", "'post'", "'asked'", "'acquired'", "'interviewed'", "'used'", "'prepare'"]
# ********************************************
# Glassdoor
# 		Intro
# 			('2018', 'CD')(',', ',')('company', 'NN')('acquired', 'VBD')('Japanese', 'JJ')('firm', 'NN')(',', ',')('Recruit', 'NNP')('Holdings', 'NNP')(',', ',')('US', 'NNP')('$', '$')('1.2', 'CD')('billion', 'CD')('.', '.')
# ["'2018'", "'acquired'", "'Recruit'", "'Holdings'", "'US'", "'$'", "'1.2'", "'billion'"]
# ...

# %%
f = open('compet', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'VB' in item.split(',')[1]:
                            if 'compet' in item.split(',')[0]:
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NNP' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    f.write(str(companykey) + ',' + str(store) + '\n')
f.close()
# Out:
# ********************************************
# SlideShare
# 		Zipcasts[edit]
# 			('Zipcasts', 'NNS')('currently', 'RB')('support', 'VBP')('screen', 'NN')('sharing', 'NN')('presenter', 'NN')(',', ',')('feature', 'NN')('available', 'JJ')('competing', 'VBG')('paid', 'VBN')('services', 'NNS')('like', 'IN')('WebEx', 'NNP')('GoToMeeting', 'NNP')('.', '.')
# ["'support'", "'competing'", "'paid'", "'WebEx'", "'GoToMeeting'"]
# ********************************************
# VK (service)
# 		Events and projects[edit]
# 			('third', 'JJ')('VK', 'NNP')('Hackathon', 'NNP')('took', 'VBD')('place', 'NN')('20', 'CD')('October', 'NNP')('22', 'CD')('October', 'NNP')('2017', 'CD')('320', 'CD')('participants', 'NNS')('competing', 'VBG')('event', 'NN')('.', '.')
# ["'VK'", "'Hackathon'", "'took'", "'20'", "'October'", "'22'", "'October'", "'2017'", "'320'", "'competing'"]
# ********************************************
# XING
# 		Intro
# ...

# %%
f = open('sued', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'VB' in item.split(',')[1]:
                            if (('sued' in item.split(',')[0]) and ('issued' not in item.split(',')[0])):
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NNP' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    f.write(str(companykey) + ',' + str(store) + '\n')
f.close()
# Out:
# ********************************************
# LinkedIn
# 		History[edit]
# 			('response', 'NN')(',', ',')('hiQ', 'NN')('sued', 'VBD')('LinkedIn', 'NNP')('Northern', 'NNP')('District', 'NNP')('California', 'NNP')('San', 'NNP')('Francisco', 'NNP')(',', ',')('asking', 'VBG')('court', 'NN')('prohibit', 'VBP')('LinkedIn', 'NN')('blocking', 'VBG')('access', 'NN')('public', 'JJ')('profiles', 'NNS')('court', 'NN')('considered', 'VBD')('merits', 'NNS')('request', 'NN')('.', '.')
# ["'sued'", "'LinkedIn'", "'Northern'", "'District'", "'California'", "'San'", "'Francisco'", "'asking'", "'prohibit'", "'blocking'", "'considered'"]
# ********************************************
# LinkedIn
# 		Criticism[edit]
# 			('LinkedIn', 'NNP')('sued', 'VBD')('United', 'NNP')('States', 'NNPS')('charges', 'NNS')('hijacking', 'VBG')('e-mail', 'NN')('accounts', 'NNS')('spamming', 'VBG')('.', '.')
# ["'LinkedIn'", "'sued'", "'United'", "'States'", "'hijacking'", "'spamming'"]
# ...

# %%
noun_set = []
for companykey in data.keys():
    print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'NN' in item.split(',')[1]:
                            #print (item.split(',')[0])
                            noun_set.append(item.split(',')[0])
print(len(noun_set))
# Out:
# LinkedIn Pulse
#       History[edit]
#       Intro
# Drawbridge (company)
#       History[edit]
#       Technology[edit]
#       Reception[edit]
#       Financials[edit]
#       Intro
# Glassdoor
#       Founding[edit]
#       Website[edit]
#       Reports[edit]
#       Financing[edit]
#       Awards[edit]
#       Intro
# Bright.com
#       Intro
# SlideShare
#       History[edit]
#       Zipcasts[edit]
#       Intro
# LinkedIn
#       Company overview[edit]
#       History[edit]
#       Membership[edit]
#       Future plans[edit]
#       New user interface in 2017[edit]
#       Discontinued features[edit]
#       Business units[edit]
#       Reception[edit]
#       International restrictions[edit]
#       SNA LinkedIn[edit]
#       Surveillance and NSA program[edit]
#       Criticism[edit]
#       Science[edit]
#       Intro
# Wirecard
#       Products and services[edit]
#       Wirecard and the Financial Times controversy[edit]
#       Financial data[edit]
# ...

# %%
stem_noun_set = []
for w in noun_set:
    stem_noun_set.append(lancaster.stem(lancaster.stem(w.replace("'",""))))
    
hash_noun_map = {}
for word in stem_noun_set:        
    if word in hash_noun_map:
        hash_noun_map[word] = hash_noun_map[word] + 1
    else:
        hash_noun_map[word] = 1
sorted_noun_hashmap = sorted(hash_noun_map.items(), key=operator.itemgetter(1),reverse=True)  
pprint.pprint(sorted_noun_hashmap)
# Out:
# [('', 2590),
#  ('us', 2427),
#  ('company', 1212),
#  ('serv', 1128),
#  ('microsoft', 742),
#  ('sit', 610),
#  ('network', 600),
#  ('off', 584),
#  ('tim', 570),
#  ('gam', 519),
#  ('develop', 516),
#  ('busy', 499),
#  ('ap', 490),
#  ('system', 469),
#  ('year', 456),
#  ('dat', 444),
#  ('web', 432),
#  ('vert', 423),
#  ('produc', 419),
#  ('cont', 414),
#  ('websit', 405),
#  ('stat', 395),
#  ('new', 381),
#  ('comput', 379),
#  ('softw', 379),
#  ('feat', 371),
#  ('window', 371),
#  ('video', 367),
#  ('memb', 351),
#  ('group', 347),
#  ('commun', 346),
#  ('apply', 340),
#  ('program', 339),
#  ('platform', 334),
#  ('googl', 324),
#  ('technolog', 324),
#  ('med', 314),
#  ('numb', 311),
#  ('peopl', 291),
#  ('inform', 286),
#  ('pag', 285),
#  ('market', 282),
#  ('account', 278),
#  ('act', 274),
#  ('man', 263),
#  ('un', 260),
#  ('may', 260),
#  ('internet', 259),
#  ('%', 259),
#  ('world', 251),
#  ('post', 247),
#  ('art', 244),
#  ('project', 240),
# ...

# %%
f = open('lawsuit', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'NN' in item.split(',')[1]:
                            if 'lawsuit' in item.split(',')[0]:
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NN' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    try:
                                        f.write(str(companykey) + ',' + str(store) + '\n')
                                    except:
                                        pass
    
f.close()
# Out:
# ********************************************
# LinkedIn
# 		History[edit]
# 			('2013', 'CD')(',', ',')('class', 'NN')('action', 'NN')('lawsuit', 'NN')('entitled', 'VBN')('Perkins', 'NNP')('vs.', 'FW')('LinkedIn', 'NNP')('Corp', 'NNP')('filed', 'VBD')('company', 'NN')(',', ',')('accusing', 'VBG')('automatically', 'RB')('sending', 'VBG')('invitations', 'NNS')('contacts', 'NNS')('member', 'NN')("'s", 'POS')('email', 'NN')('address', 'NN')('book', 'NN')('without', 'IN')('permission', 'NN')('.', '.')
# ["'2013'", "'class'", "'action'", "'lawsuit'", "'entitled'", "'Perkins'", "'LinkedIn'", "'Corp'", "'filed'", "'company'", "'accusing'", "'sending'", "'invitations'", "'contacts'", "'member'", "'email'", "'address'", "'book'", "'permission'"]
# ********************************************
# Wirecard
# 		Wirecard and the Financial Times controversy[edit]
# ...

# %%
f = open('competit', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'NN' in item.split(',')[1]:
                            if 'competit' in item.split(',')[0]:
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NN' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    try:
                                        f.write(str(companykey) + ',' + str(store) + '\n')
                                    except:
                                        pass
    
f.close()

# %%
f = open('purcha', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'NN' in item.split(',')[1]:
                            if 'purcha' in item.split(',')[0]:
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NN' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    try:
                                        f.write(str(companykey) + ',' + str(store) + '\n')
                                    except:
                                        pass
    
f.close()
# Out:
# ********************************************
# LinkedIn Pulse
# 		History[edit]
# 			('stated', 'VBN')('reason', 'NN')('change', 'NN')('deliver', 'VB')('personalized', 'JJ')('news', 'NN')('user', 'NN')("'s", 'POS')('professional', 'JJ')('network', 'NN')('(', 'NN')('primarily', 'RB')('LinkedIn', 'NN')(',', ',')('purchaser', 'NN')('Pulse', 'NN')(')', 'NN')(',', ',')('allow', 'VBP')('little', 'JJ')('none', 'NN')('user', 'NN')('customization', 'NN')('.', '.')
# ["'stated'", "'reason'", "'change'", "'deliver'", "'news'", "'user'", "'network'", "''", "'LinkedIn'", "'purchaser'", "'Pulse'", "'", "'allow'", "'none'", "'user'", "'customization'"]
# ********************************************
# Wirecard
# 		Products and services[edit]
# 			('2016', 'CD')(',', ',')('together', 'RB')('WMF', 'NNP')('Group', 'NNP')(',', ',')('Wirecard', 'NNP')('developed', 'VBD')('mobile', 'JJ')('app', 'NN')('connects', 'VBZ')('store', 'NN')('purchases', 'NNS')('online', 'JJ')('sales', 'NNS')('.', '.')
# ...

# %%
f = open('purcha_vb', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'VB' in item.split(',')[1]:
                            if 'purcha' in item.split(',')[0]:
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NN' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    try:
                                        f.write(str(companykey) + ',' + str(store) + '\n')
                                    except:
                                        pass
    
f.close()
# Out:
# ********************************************
# LinkedIn
# 		History[edit]
# 			('June', 'NNP')('2008', 'CD')(',', ',')('Sequoia', 'NNP')('Capital', 'NNP')(',', ',')('Greylock', 'NNP')('Partners', 'NNPS')(',', ',')('venture', 'NN')('capital', 'NN')('firms', 'NNS')('purchased', 'VBD')('5', 'CD')('%', 'NN')('stake', 'NN')('company', 'NN')('$', '$')('53', 'CD')('million', 'CD')(',', ',')('giving', 'VBG')('company', 'NN')('post-money', 'JJ')('valuation', 'NN')('approximately', 'RB')('$', '$')('1', 'CD')('billion', 'CD')('.', '.')
# ["'June'", "'2008'", "'Sequoia'", "'Capital'", "'Greylock'", "'Partners'", "'venture'", "'capital'", "'firms'", "'purchased'", "'5'", "'%'", "'stake'", "'company'", "'$'", "'53'", "'million'", "'giving'", "'company'", "'valuation'", "'$'", "'1'", "'billion'"]
# ********************************************
# Wirecard
# 		Products and services[edit]
# ...

# %%
f = open('invest', "w")

for companykey in data.keys():
    #print (companykey)
    GD_json = data[companykey]
    for key in GD_json:
        if ('edit' in key or 'Intro' in key) and ('References' not in key) and ('See also' not in key) and ('External links' not in key):
            #print ('      '+key)
            if isinstance (GD_json[key][2],dict):
                pos = GD_json[key][2]
            elif isinstance (GD_json[key][3],dict):
                pos = GD_json[key][3]
            else:
                continue
            for sentence in pos.keys():
                for item in pos[sentence].replace("(","").split(')'):
                    if len(item.split(','))>1:
                        if 'NN' in item.split(',')[1]:
                            if 'invest' in item.split(',')[0]:
                                print ("********************************************")
                                print (companykey)
                                print ("\t\t" + key)
                                print ("\t\t\t" + pos[sentence])
                                #if ((input("Wanna save this?"))=='Y'):
                                if (1):
                                    store = []
                                    for x in pos[sentence].replace("(","").split(')'):
                                        tuple_item_again = x.split(',');
                                        if len(tuple_item_again)>1:
                                            if (('VB' in x.split(',')[1]) or ('NN' in x.split(',')[1]) or ('CD' in x.split(',')[1] or ('$' in x.split()[1]))):
                                                store.append(x.split(',')[0])
                                    print (store);
                                    try:
                                        f.write(str(companykey) + ',' + str(store) + '\n')
                                    except:
                                        pass
    
f.close()
# Out:
# ********************************************
# Glassdoor
# 		Financing[edit]
# 			('2015', 'CD')('company', 'NN')('raised', 'VBD')('additional', 'JJ')('$', '$')('70', 'CD')('million', 'CD')(',', ',')('investment', 'NN')('round', 'NN')('led', 'VBD')('Google', 'NNP')('Capital', 'NNP')(',', ',')('giving', 'VBG')('company', 'NN')('valuation', 'NN')('short', 'JJ')('$', '$')('1', 'CD')('billion', 'CD')('.', '.')
# ["'2015'", "'company'", "'raised'", "'$'", "'70'", "'million'", "'investment'", "'round'", "'led'", "'Google'", "'Capital'", "'giving'", "'company'", "'valuation'", "'$'", "'1'", "'billion'"]
# ********************************************
# LinkedIn
# 		History[edit]
# 			('late', 'RB')('2003', 'CD')(',', ',')('Sequoia', 'NNP')('Capital', 'NNP')('led', 'VBD')('Series', 'NNP')('investment', 'NN')('company', 'NN')('.', '.')
# ["'2003'", "'Sequoia'", "'Capital'", "'led'", "'Series'", "'investment'", "'company'"]
# ********************************************
# LinkedIn
# ...
